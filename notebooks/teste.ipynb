# %%
import pandas as pd

# %%
df = pd.read_csv('../data/TS_ALUNO_2014.csv')

# %%
df
# Out:
#          ID_EXAME_ANA  ID_REGIAO  ID_UF  ID_MUNICIPIO  ID_AREA  ID_ESCOLA  \
# 0                2014          1     11       6069215        1   60055838
# 1                2014          1     11       6069215        1   60055838
# 2                2014          1     11       6069215        1   60055838
# 3                2014          1     11       6069215        1   60055838
# 4                2014          1     11       6069215        1   60055838
# ...               ...        ...    ...           ...      ...        ...
# 2708370          2014          5     53       6104484        1   60105625
# 2708371          2014          5     53       6104484        1   60105625
# 2708372          2014          5     53       6104484        1   60105625
# 2708373          2014          5     53       6104484        1   60105625
# 2708374          2014          5     53       6104484        1   60105625
#
#          IN_PUBLICA  ID_LOCALIZACAO  ID_TURMA  ID_SERIE  ...  \
# ...
