# %%
import pandas as pd

# %%
df = pd.read_csv('../data/Google_Ads_Dataset.csv')

# %%
df.sample(10)
# Out:
#       Ad_ID             Campaign_Name  Clicks  Impressions     Cost  Leads  \
# 1245  A2245  cYBERsECURTYfUNDAMENTALS   194.0       3751.0  $244.34   23.0
# 1720  A2720     Businessanlyticsclass    92.0       5952.0  $192.35   30.0
# 2168  A3168             wEBdEVmASTERY   131.0       5719.0  $183.69   12.0
# 554   A1554  CyberSecurtyFundamentals   151.0       5595.0  $246.66   24.0
# 1391  A2391             wEBdEVmASTERY   197.0       5921.0  $214.97   18.0
# 2008  A3008  Cyb3rSecurtyFundamentals    95.0       4653.0  $193.63   17.0
# 2577  A3577       DataSci3nceBootcamp    91.0       4893.0   $222.3   29.0
# 533   A1533     BusinessAnlyticsClass   113.0       5407.0  $203.23   15.0
# 1354  A2354        SQLDatabs3Training   118.0       4390.0  $214.04   24.0
# 703   A1703            WebDevMastery     94.0       4544.0  $235.77   23.0
#
#       Conversions  Conversion Rate Sale_Amount     Ad_Date   Location  \
# 1245          5.0            0.026         NaN  02-11-2024     mumbai
# ...
