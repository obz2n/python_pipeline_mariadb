# %%
import pandas as pd

# %%
df = pd.read_csv('../data/Google_Ads_Dataset.csv')

# %%
df
# Out:
#       Ad_ID             Campaign_Name  Clicks  Impressions     Cost  Leads  \
# 0     A1000  CyberSecurtyFundamentals   104.0       4498.0  $231.88   14.0
# 1     A1001        SQLDatabseTraining   173.0       5107.0  $216.84   10.0
# 2     A1002               Python4D@ta    90.0       4544.0  $203.66   26.0
# 3     A1003          AI_Marketing1011   142.0       3185.0  $237.66   17.0
# 4     A1004       SQLDatabseTraining1   156.0       3361.0   $195.9   30.0
# ...     ...                       ...     ...          ...      ...    ...
# 2595  A3595      Machnelearningbasics    88.0       5344.0  $242.07   17.0
# 2596  A3596           AI_Mark3ting101   154.0       3211.0  $248.28   14.0
# 2597  A3597      Machn3LearningBasics   113.0       3808.0  $233.25   18.0
# 2598  A3598      DataScienceBootcamp1   196.0       5853.0  $220.13   16.0
# 2599  A3599      mACHNElEARNINGbASICS     NaN       5453.0      NaN   12.0
#
# ...
